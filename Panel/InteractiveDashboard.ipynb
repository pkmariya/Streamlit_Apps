# %%
import numpy as np
import pandas as pd
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e4a3cb8d-c979-4baa-a7f8-2821c57cec0a'>
#   <div id="bef21cb2-475a-40f7-8d02-ab75118e9e2d" data-root-id="e4a3cb8d-c979-4baa-a7f8-2821c57cec0a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"070c6d43-3654-4db4-acb4-eae842f7f7f1":{"version":"3.3.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e4a3cb8d-c979-4baa-a7f8-2821c57cec0a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"60b66d57-1d54-4503-904c-7ae5c32554b8","attributes":{"plot_id":"e4a3cb8d-c979-4baa-a7f8-2821c57cec0a","comm_id":"55bd4da38f6640b59a15b371ad155a0a","client_comm_id":"ec3c91524e394db3b47a0147354dafc7"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"070c6d43-3654-4db4-acb4-eae842f7f7f1","roots":{"e4a3cb8d-c979-4baa-a7f8-2821c57cec0a":"bef21cb2-475a-40f7-8d02-ab75118e9e2d"},"root_ids":["e4a3cb8d-c979-4baa-a7f8-2821c57cec0a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# df = pd.read_csv('/Users/mariya/pers/Learnings/Data Science/DataSets/World_Bank_CO2.xlsx')
df = pd.read_csv('/Users/mariya/pers/Learnings/Data Science/DataSets/World_Bank_CO2_Data.csv')

# %%
df = pd.read_csv('/Users/mariya/pers/Learnings/Data Science/DataSets/World_Bank_CO2.csv')

# %%
df.head()
# Out:
#   Country Code Country Name                     Region  Year CO2 (kt)  \
# 0          ABW        Aruba  Latin America & Caribbean  1960      NaN
# 1          ABW        Aruba  Latin America & Caribbean  1961      NaN
# 2          ABW        Aruba  Latin America & Caribbean  1962      NaN
# 3          ABW        Aruba  Latin America & Caribbean  1963      NaN
# 4          ABW        Aruba  Latin America & Caribbean  1964      NaN
#
#    CO2 Per Capita (metric tons)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN

# %%
df.Region.unique()
# Out:
# array(['Latin America & Caribbean', 'Europe & Central Asia', 'South Asia',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country Code                  11127 non-null  object
#  1   Country Name                  11127 non-null  object
#  2   Region                        11127 non-null  object
#  3   Year                          11127 non-null  int64
#  4   CO2 (kt)                      9032 non-null   object
#  5   CO2 Per Capita (metric tons)  9029 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 521.7+ KB

# %%
print("Given dataset contains {0} Rows and {1} Columns".format(df.shape[0], df.shape[1]))
# Out:
# Given dataset contains 11127 Rows and 6 Columns

# %%
df.columns
# Out:
# Index(['Country Code', 'Country Name', 'Region', 'Year', 'CO2 (kt)',
#        'CO2 Per Capita (metric tons)'],
#       dtype='object')

# %% [markdown]
# ## Some minor data pre-processing

# %%
# fill NAs with 0s
df = df.fillna(1)

# %%
df.isna().sum()
# Out:
# Country Code                    0
# Country Name                    0
# Region                          0
# Year                            0
# CO2 (kt)                        0
# CO2 Per Capita (metric tons)    0
# dtype: int64

# %%
df["CO2 Per Capita (metric tons)"]
# Out:
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
#            ...
# 11122    0.731867
# 11123    0.569255
# 11124    0.600521
# 11125    0.646073
# 11126    0.691698
# Name: CO2 Per Capita (metric tons), Length: 11127, dtype: float64

# %%
#  Make DataFrame Pipeline Interactive
idf = df.interactive()

# %%
# Define Panel Widgets
year_slider = pn.widgets.IntSlider(name='Year Slider', start=1960, end=2011, step=5, value=1970)
year_slider
# Out:
# IntSlider(end=2011, name='Year Slider', start=1960, step=5, value=1970)

# %%
df['CO2 Per Capita (metric tons)'].mean()
# Out:
# 3.71090852582547

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name = 'Y axis',
    options = ['CO2 Per Capita (metric tons)'],
    button_type = 'success'
)

# %%
yaxis_co2
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['CO2 Per Capita (...], value='CO2 Per Capita (...)

# %%
continents = ['Latin America & Caribbean', 'Europe & Central Asia', 'South Asia',
       'Sub-Saharan Africa', 'Middle East & North Africa',
       'East Asia & Pacific', 'North America']

# %%
continents
# Out:
# ['Latin America & Caribbean',
#  'Europe & Central Asia',
#  'South Asia',
#  'Sub-Saharan Africa',
#  'Middle East & North Africa',
#  'East Asia & Pacific',
#  'North America']

# %%
co2_pipeline = (
    idf[
        (idf.Year <= year_slider)
    ]
    .groupby(['Country Name', 'Year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='bcfbed1d-503f-4d6b-b9c8-14fd86d88b29'>
#   <div id="c708c527-c42c-44f4-9965-c95ca416503d" data-root-id="bcfbed1d-503f-4d6b-b9c8-14fd86d88b29" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"188a477a-fb73-4d6f-b1a0-2682ac41b84a":{"version":"3.3.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"bcfbed1d-503f-4d6b-b9c8-14fd86d88b29","attributes":{"name":"Row26992","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"d9372e59-6203-4db3-b314-9e8a2f5cfc41","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"ab3c45d1-d895-42b0-a220-51caeb162215","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"cc72320c-c50f-496f-8d84-2a4618b80965","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"65bef09a-0916-41b8-9c41-006ecf3144f3","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"e092e60e-1e29-4cfd-aaff-db4cecb74cee","attributes":{"name":"Column26991","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d9372e59-6203-4db3-b314-9e8a2f5cfc41"},{"id":"ab3c45d1-d895-42b0-a220-51caeb162215"},{"id":"cc72320c-c50f-496f-8d84-2a4618b80965"},{"id":"65bef09a-0916-41b8-9c41-006ecf3144f3"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"552b4150-c27b-40d5-99a6-319c10e17820","attributes":{"name":"Column26983","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d9372e59-6203-4db3-b314-9e8a2f5cfc41"},{"id":"ab3c45d1-d895-42b0-a220-51caeb162215"},{"id":"cc72320c-c50f-496f-8d84-2a4618b80965"},{"id":"65bef09a-0916-41b8-9c41-006ecf3144f3"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"d9876ade-6b84-4fda-ad49-01aa994e6441","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d9372e59-6203-4db3-b314-9e8a2f5cfc41"},{"id":"cc72320c-c50f-496f-8d84-2a4618b80965"},{"id":"65bef09a-0916-41b8-9c41-006ecf3144f3"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1960,"end":2011,"value":1990,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"351e58f7-5072-4897-a9e8-60a5d49419f6","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d9372e59-6203-4db3-b314-9e8a2f5cfc41"},{"type":"object","name":"ImportedStyleSheet","id":"abe3de69-7582-4a66-bf29-dc6f06a56d73","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/css/button.css"}},{"id":"cc72320c-c50f-496f-8d84-2a4618b80965"},{"id":"65bef09a-0916-41b8-9c41-006ecf3144f3"}],"margin":[5,10],"align":"start","labels":["CO2 (kt)","CO2 Per Capita (metric tons)"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"60b7f7f2-f6b2-4083-814a-054dc4d885aa","attributes":{"name":"Column26988","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"d9372e59-6203-4db3-b314-9e8a2f5cfc41"},{"id":"ab3c45d1-d895-42b0-a220-51caeb162215"},{"id":"cc72320c-c50f-496f-8d84-2a4 ...

# %%
co2_plot = co2_pipeline.hvplot(x='Year', by='Country Name', y=yaxis_co2, line_width=2, title="CO2 Emission by Contient")

# %%
co2_plot
# Out:
# <div id='89228433-d2d1-4668-aedd-a467930ebd51'>
#   <div id="e397fa0b-752e-4d79-9473-247f4e7f1fb6" data-root-id="89228433-d2d1-4668-aedd-a467930ebd51" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"25ccaa6a-909f-4c68-8034-57945cc4e44b":{"version":"3.3.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"89228433-d2d1-4668-aedd-a467930ebd51","attributes":{"name":"Row50237","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":
attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"163acd38-9148-43eb-97cb-9348ad82a235"},{"id":"958fb560-f9ef-4586-b767-abee051e2f31"},{"id":"55525f52-b53b-48c0-8306-8a562a035dfe"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1960,"end":2011,"value":1970,"step":5}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"3f8ef73b-0bbe-4ebf-aa36-5d3447127366","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"163acd38-9148-43eb-97cb-9348ad82a235"},{"type":"object","name":"ImportedStyleSheet","id":"96d29948-2977-4652-97bd-92346f80bc07","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/css/button.css"}},{"id":"958fb560-f9ef-4586-b767-abee051e2f31"},{"id":"55525f52-b53b-48c0-8306-8a562a035dfe"}],"margin":[5,10],"align":"start","labels":["CO2 Per Capita (metric tons)"],"active":0}}]}},{"type":"object","name":"panel.models.layout.Column","id":"00d3d604-2696-473b-a178-954586359f82","attributes":{"name":"Column53304","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"163acd38-9148-43eb-97cb-9348ad82a235"},{"id":"97671af9-ed69-43c2-8993- ...

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.Year == year_slider)
    ]
    .groupby(['Country Name', 'Year', 'CO2 (kt)'])['CO2 Per Capita (metric tons)'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='Year')
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='1ea49e7a-8f84-4389-959a-15b11a85ef79'>
#   <div id="ae41c4af-7b11-49cb-9f76-5f7c3d11c87a" data-root-id="1ea49e7a-8f84-4389-959a-15b11a85ef79" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1875a779-beb0-468c-be63-d1c6afc80a6d":{"version":"3.3.2","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"1ea49e7a-8f84-4389-959a-15b11a85ef79","attributes":{"name":"Row69752","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"28ca1725-d28d-48a7-a117-753dc37d0158","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"36b9ab5c-16c2-4ef8-871e-5c6de277a744","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5f994160-a05a-4117-8a72-7dd4193359b5","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"894e5f15-19f7-4ef0-95bb-a1181b738509","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"5ea11eed-137e-4352-830b-b7bd742edf08","attributes":{"name":"Column69751","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"28ca1725-d28d-48a7-a117-753dc37d0158"},{"id":"36b9ab5c-16c2-4ef8-871e-5c6de277a744"},{"id":"5f994160-a05a-4117-8a72-7dd4193359b5"},{"id":"894e5f15-19f7-4ef0-95bb-a1181b738509"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"643fad1f-d406-4f4f-b8af-069aab3aaf47","attributes":{"name":"Column69743","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"28ca1725-d28d-48a7-a117-753dc37d0158"},{"id":"36b9ab5c-16c2-4ef8-871e-5c6de277a744"},{"id":"5f994160-a05a-4117-8a72-7dd4193359b5"},{"id":"894e5f15-19f7-4ef0-95bb-a1181b738509"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"71fd61c2-6ad4-43d7-9e4f-f9ff8dee0640","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"28ca1725-d28d-48a7-a117-753dc37d0158"},{"id":"5f994160-a05a-4117-8a72-7dd4193359b5"},{"id":"894e5f15-19f7-4ef0-95bb-a1181b738509"}],"margin":[5,10],"align":"start","title":"Year Slider","start":1960,"end":2011,"value":1975,"step":5}}]}},{"type":"object","name":"panel.models.layout.Column","id":"1074ce33-f88d-4021-b1fd-23f7b55572d7","attributes":{"name":"Column69748","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"28ca1725-d28d-48a7-a117-753dc37d0158"},{"id":"36b9ab5c-16c2-4ef8-871e-5c6de277a744"},{"id":"5f994160-a05a-4117-8a72-7dd4193359b5"},{"id":"894e5f15-19f7-4ef0-95bb-a1181b738509"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"d869ad19-cac4-494d-89c9-39f2eda09bf2","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"28ca1725-d28d-48a7-a117-753dc37d0158"},{"type":"object","name":"ImportedStyleSheet","id":"b42913bf-672d-4b98-98be-f84057318bac","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.6/dist/css/dataframe.css"}},{"id":"5f994160-a05a-4117-8a72-7dd4193359b5"},{"id":"894e5f15-19f7-4ef0-95bb-a1181b738509"}],"margin":[5,10],"align":"start","text":"&lt;table class=&q ...

# %%
df.columns
# Out:
# Index(['Country Code', 'Country Name', 'Region', 'Year', 'CO2 (kt)',
#        'CO2 Per Capita (metric tons)'],
#       dtype='object')

# %%
df['CO2 (kt)'].unique()
# Out:
# array([1, '179.683', '447.374', ..., '9,864.23', '10,249.27', '9,860.56'],
#       dtype=object)
